# %%
import pickle
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/data1/History_config_one', 'rb') as file:
	config1 = pickle.load(file)
 
with open('/content/gdrive/My Drive/data2/History_config_two', 'rb') as file:
	config2 = pickle.load(file)

with open('/content/gdrive/My Drive/data3/History_config_three', 'rb') as file:
	config3 = pickle.load(file)

with open('/content/gdrive/My Drive/data4/History_config_four', 'rb') as file:
	config4 = pickle.load(file)
 
 
with open('/content/gdrive/My Drive/data5/History_config_five', 'rb') as file:
	config5 = pickle.load(file)
 
with open('/content/gdrive/My Drive/data6/History_config_six', 'rb') as file:
	config6 = pickle.load(file)

with open('/content/gdrive/My Drive/data7/History_config_seven', 'rb') as file:
	config7 = pickle.load(file)

with open('/content/gdrive/My Drive/data8/History_config_oct', 'rb') as file:
	config8 = pickle.load(file)
  

with open('/content/gdrive/My Drive/data9/History_config_nona', 'rb') as file:
	config9 = pickle.load(file)
 
 
with open('/content/gdrive/My Drive/data10/History_config_dec', 'rb') as file:
	config10 = pickle.load(file)

# %%
with open('/content/gdrive/My Drive/data11/History_config_undec', 'rb') as file:
	config11 = pickle.load(file)

# %%
print(np.mean(config1['loss']))

print(np.mean(config1['acc']))
print(np.mean(config1['val_loss']))
print(np.mean(config1['val_acc']))
# Out:
# 0.3909148348028287
# 0.8597368
# 0.4370475403028622
# 0.8432351

# %%
import numpy as np



print(np.mean(config2['loss']))

print(np.mean(config2['acc']))
print(np.mean(config2['val_loss']))
print(np.mean(config2['val_acc']))
# Out:
# 0.38366945652388745
# 0.89636433
# 0.3974415224726711
# 0.8889358

# %%
print(np.mean(config3['loss']))
print(np.mean(config3['acc']))
print(np.mean(config3['val_loss']))
print(np.mean(config3['val_acc']))
# Out:
# 0.4033169850559449
# 0.88140345
# 0.3985650033801795
# 0.88302636

# %%
print(np.mean(config4['loss']))
print(np.mean(config4['acc']))
print(np.mean(config4['val_loss']))
print(np.mean(config4['val_acc']))
# Out:
# 0.3574285155124714
# 0.90217865
# 0.368469618037641
# 0.8959581

# %%
print(np.mean(config5['loss']))

print(np.mean(config5['acc']))
print(np.mean(config5['val_loss']))
print(np.mean(config5['val_acc']))
# Out:
# 0.354754379984069
# 0.89226043
# 0.3611565526919439
# 0.8884219

# %%
print(np.mean(config6['loss']))

print(np.mean(config6['acc']))
print(np.mean(config6['val_loss']))
print(np.mean(config6['val_acc']))
# Out:
# 0.334256249374751
# 0.89704376
# 0.34479101797994594
# 0.8932377

# %%
print(np.mean(config7['loss']))

print(np.mean(config7['acc']))
print(np.mean(config7['val_loss']))
print(np.mean(config7['val_acc']))
# Out:
# 0.42753083000020625
# 0.8597082
# 0.3905899409451933
# 0.8743677

# %%
print(np.mean(config8['loss']))

print(np.mean(config8['acc']))
print(np.mean(config8['val_loss']))
print(np.mean(config8['val_acc']))
# Out:
# 0.15645076628866128
# 0.9428599
# 0.22438219592534006
# 0.9242727

# %%
print(np.mean(config9['loss']))

print(np.mean(config9['acc']))
print(np.mean(config9['val_loss']))
print(np.mean(config9['val_acc']))
# Out:
# 0.3963371787444846
# 0.8586819
# 0.42525650541314425
# 0.8480237

# %%
print(np.mean(config10['loss']))

print(np.mean(config10['acc']))
print(np.mean(config10['val_loss']))
print(np.mean(config10['val_acc']))
# Out:
# 0.489454498115513
# 0.87149894
# 0.35946878995001313
# 0.8663667

# %%
print(np.mean(config11['loss']))

print(np.mean(config11['acc']))
print(np.mean(config11['val_loss']))
print(np.mean(config11['val_acc']))
# Out:
# 0.9033036167294265
# 0.72541744
# 0.9059254839775791
# 0.7243819

# %%
plt.plot(config1['val_acc'], 'b')
plt.plot(config2['val_acc'], 'g')
plt.plot(config3['val_acc'], 'y')
plt.plot(config4['val_acc'], 'r')
plt.title('(Different CNN config with SGD)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Config-1', 'Config-2', 'Config-3','Config-4'], loc='lower right')
plt.savefig('/content/gdrive/My Drive/graphs/1.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(config8['val_acc'], 'b')
plt.plot(config9['val_acc'], 'g')
plt.plot(config10['val_acc'], 'y')
plt.plot(config11['val_acc'], 'r')
plt.title('Comparison of VCC,Alexnet,Inception,Resnet')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Config-8', 'Config-9', 'Config-10','Config-11'], loc='lower right')
plt.savefig('/content/gdrive/My Drive/graphs/2.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(config3['val_acc'], 'b')
plt.plot(config5['val_acc'], 'g')
plt.plot(config6['val_acc'], 'r')

plt.title('Comparison of optimizer SGD, RMS, ADAM')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Config-3', 'Config-5', 'Config-6'], loc='lower right')
plt.savefig('/content/gdrive/My Drive/graphs/3.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(config2['val_acc'], 'g')
plt.plot(config3['val_acc'], 'b')
plt.plot(config4['val_acc'], 'r')
plt.title('(Different ACtivation function Comparison')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Config-2', 'Config-3', 'Config-4'], loc='lower right')
plt.savefig('/content/gdrive/My Drive/graphs/4.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(config1['val_acc'], 'g')
plt.plot(config2['val_acc'], 'r')
plt.title('(Comparison of regularization and without regularization')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Config-1', 'Config-2'], loc='lower right')
plt.savefig('/content/gdrive/My Drive/graphs/5.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(config6['val_acc'], 'g')
plt.plot(config7['val_acc'], 'r')
plt.title('(Comparison of with and without Data Argumentation')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Config-6', 'Config-7'], loc='lower right')
plt.savefig('/content/gdrive/My Drive/graphs/6.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>
